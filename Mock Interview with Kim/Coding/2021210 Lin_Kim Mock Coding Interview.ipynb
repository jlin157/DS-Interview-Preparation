# %% [markdown]
# ### Python Q1 ###

# %% [markdown]
# 1.Create this dataframe and show it in console
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2.Add a column called N^2 that contains the square of each number, show the new dataframe in the console. These should square the values in Numbers

# %% [markdown]
# 3.Create a Numpy array of the values from the columns ‘Numbers’ and ‘N^2’. Show the array in the console

# %% [markdown]
# 4.Create a function that takes a number, if the number is even, it should return the number squared. (i.e. if given 2, return 4). If the number is odd, it should return the number squared plus one (i.e. if given 3, return 10)
# Call the function with 2 and then with 3
# Call the function on an additional odd and even number of your choice

# %% [markdown]
# 5.Create a Class with a single method (other than init). This method should not require any additional arguments when called. Each time the method is called, it should switch between returning the word “Odd” or “Even”. This should reliably switch every time.

# %% [markdown]
# ### SQL Q1 ###

# %% [markdown]
# """
#
# 2) Write a query to rank customers in terms of 2017 sales units (largest to smallest).  Return the top 100 customers, their unit sales, and their rank.  Also include a column called TOP_10_FLG that is 'Y' for the top 10 customers and 'N' for all other customers.
#
# """
# """
# ![ad209fb0d4b516aafe2e77f5e32f9f1.png](attachment:ad209fb0d4b516aafe2e77f5e32f9f1.png)
# """
